# %%
from sys import exit
#setup
print('for input, you have to enter one of these numbers, they correspond to the tic tac toe board like this.')
print('1 2 3')
print('4 5 6')
print('7 8 9')
# Out:
# for input, you have to enter one of these numbers, they correspond to the tic tac toe board like this.
# 1 2 3
# 4 5 6
# 7 8 9

# %%
def getboard(listofmoves, playerinfo):
    i = 0
    listofplaces = ['-', '-', '-', '-', '-', '-', '-', '-', '-']
    playerXorO = playerinfo[0]
    playerstartfirst = playerinfo[1]
    XorO = 'X'
    for i in range(len(listofmoves)):
        n = listofmoves[i]
        listofplaces[n - 1] = XorO
        if XorO == 'O':
            XorO = 'X'
        else:
            XorO = 'O'
    #resetting player start first to original state
    playerstartfirst = playerinfo[1]
    
    print(listofplaces[0], listofplaces[1], listofplaces[2])
    print(listofplaces[3], listofplaces[4], listofplaces[5])
    print(listofplaces[6], listofplaces[7], listofplaces[8])
    return listofplaces

# %%
def gameinput(listofmoves, counter, playerinfo, AImove):
    playerstartfirst = playerinfo[1]
    if playerstartfirst:
        if counter % 2 == 0:
            return AImove
        else:
            #keepgoing = True
            #while keepgoing:
            noForInput = input('please enter the input number of where you would like your piece to be placed')
                #i = 0
                #for i in range(len(listofmoves)):
                    #if noForinput == listofmoves[i]:
                        #keepgoing = True
                    #else:
                        #keepgoing = False
            i = 0
            for i in range(len(listofmoves)):
                if int(noForInput) == listofmoves[i]:
                    print()
                    print()
                    print('Please only submit a number you haven\'t already.')
                    exit()
            return int(noForInput)
    else:
        if counter % 2 == 1:
            #keepgoing = True
            #while keepgoing:
            noForInput = input('please enter the input number of where you would like your piece to be placed')
                #i = 0
                #for i in range(len(listofmoves)):
                    #if noForinput == listofmoves[i]:
                        #keepgoing = True
                    #else:
                        #keepgoing = False
            i = 0
            for i in range(len(listofmoves)):
                if int(noForInput) == listofmoves[i]:
                    print()
                    print()
                    print('Please only submit a number you haven\'t already.')
                    exit()
            return int(noForInput)
        else:
            return AImove

# %%
def howManySpaces(listofplaces2):
    i = 0
    counter = 0
    for i in range(len(listofplaces2)):
        if listofplaces2[i] == '-':
            counter = counter + 1
    return counter

# %%
def pieceALTER(CPUpiece):
    if CPUpiece == 'O':
        CPUpiece = 'X'
    else:
        CPUpiece = 'O'
    return CPUpiece

# %%
def gameOver(listofplaces):
    gameOver = False
    Cause = ''
    #012------
    #0---4---8
    #---345---
    #------678
    #--2-4-6--
    #0--3--6--
    #-1--4--7-
    #--2--5--8
    #MAKE SPECIFIC
    if listofplaces[0] == 'X':
        if listofplaces[1] == 'X':
            if listofplaces[2] == 'X':
                gameOver = True
                Cause = 'Win By X'

    if listofplaces[0] == 'X':
        if listofplaces[4] == 'X':
            if listofplaces[8] == 'X':
                gameOver = True
                Cause = 'Win By X'
    if listofplaces[3] == 'X':
        if listofplaces[4] == 'X':
            if listofplaces[5] == 'X':
                gameOver = True
                Cause = 'Win By X'
    if listofplaces[6] == 'X':
        if listofplaces[7] == 'X':
            if listofplaces[8] == 'X':
                gameOver = True
                Cause = 'Win By X'
    if listofplaces[2] == 'X':
        if listofplaces[4] == 'X':
            if listofplaces[6] == 'X':
                gameOver = True
                Cause = 'Win By X'
    if listofplaces[0] == 'X':
        if listofplaces[3] == 'X':
            if listofplaces[6] == 'X':
                gameOver = True
                Cause = 'Win By X'
    if listofplaces[1] == 'X':
        if listofplaces[4] == 'X':
            if listofplaces[7] == 'X':
                gameOver = True
                Cause = 'Win By X'
    if listofplaces[2] == 'X':
        if listofplaces[5] == 'X':
            if listofplaces[8] == 'X':
                gameOver = True
                Cause = 'Win By X'
    
    
    if listofplaces[0] == 'O':
        if listofplaces[1] == 'O':
            if listofplaces[2] == 'O':
                gameOver = True
                Cause = 'Win By O'

    if listofplaces[0] == 'O':
        if listofplaces[4] == 'O':
            if listofplaces[8] == 'O':
                gameOver = True
                Cause = 'Win By O'
    if listofplaces[3] == 'O':
        if listofplaces[4] == 'O':
            if listofplaces[5] == 'O':
                gameOver = True
                Cause = 'Win By O'
    if listofplaces[6] == 'O':
        if listofplaces[7] == 'O':
            if listofplaces[8] == 'O':
                gameOver = True
                Cause = 'Win By O'
    if listofplaces[2] == 'O':
        if listofplaces[4] == 'O':
            if listofplaces[6] == 'O':
                gameOver = True
                Cause = 'Win By O'
    if listofplaces[0] == 'O':
        if listofplaces[3] == 'O':
            if listofplaces[6] == 'O':
                gameOver = True
                Cause = 'Win By O'
    if listofplaces[1] == 'O':
        if listofplaces[4] == 'O':
            if listofplaces[7] == 'O':
                gameOver = True
                Cause = 'Win By O'
    if listofplaces[2] == 'O':
        if listofplaces[5] == 'O':
            if listofplaces[8] == 'O':
                gameOver = True
                Cause = 'Win By O'

    if gameOver == False:
        if howManySpaces(listofplaces) == 0:
            gameOver = True
            Cause = 'Draw'
        else:
            gameOver = False
            Cause = ''
        
    return [gameOver, Cause]

# %%
def AITEST(playerinfo, listofplaces, howManySpaces):
    end = []
    listoflists4start = []
    if playerinfo[0] == 'X':
        CPUpiece = 'O'
    else:
        CPUpiece = 'X'
    listofplaces2 = listofplaces
    a = 0
    for a in range(howManySpaces(listofplaces2)):
        listofplaces2 = listofplaces
        count = a
        new1 = AI2(count, end)
        listoflists4start.append(new1)
        listofplaces2 = new1
        b = 0
        for b in range(howManySpaces(listofplaces2)):
            new2 = AI2(count, end)
            listofplaces2 = new2

# %%
def piece2add(listofplaces):
    X = 0
    O = 0
    i = 0
    for i in range(len(listofplaces)):
        if listofplaces[i] == 'O':
            O = O + 1
        if listofplaces[i] == 'X':
            X = X + 1
    if X == O:
        return 'X'
    else:
        return '0'

def AIrun(playerinfo, listofplaces, howManySpaces):
    start = []
    end = []
    counter = howManySpaces(listofplaces)
    return AITEST2(playerinfo, listofplaces, howManySpaces, start, end, counter)

def AITEST2(playerinfo, listofplaces, howManySpaces, start, end, counter):
    i = 0
    newlist = listofplaces
    piece2add = piece2add(listofplaces)
    for i in range(howManySpaces(listofplaces)):
        new
        if counter < 9:

# %%
playerXorOstr = input('x or o')
listofplayerXorO = list(playerXorOstr)
if listofplayerXorO[0]== ('x'):
    playerXorO = 'X'
    playerstartfirst = True
    playerinfo = [playerXorO, playerstartfirst]
    print('You will be going first')
    
elif listofplayerXorO[0] == ('o'):
    playerXorO = 'O'
    playerstartfirst = False
    playerinfo = [playerXorO, playerstartfirst]
    print('You will be going second')
else:
    print('Please use an x or an o next time')
    exit()
# Out:
# x or o o
# You will be going second

# %%
listofmoves = []
GameOn = True
i = 0
counter = 1
while GameOn:
    listofplaces = getboard(listofmoves, playerinfo)
    if playerinfo[1]:
        if counter % 2 == 0:
            AImove = AI(playerinfo, listofplaces)
            gameinputint = gameinput(listofmoves, counter, playerinfo, AImove)
        else:
            AImove = 0
            gameinputint = gameinput(listofmoves, counter, playerinfo, AImove)
    else:
        if counter % 2 == 1:
            AImove = AI(playerinfo, listofplaces)
            gameinputint = gameinput(listofmoves, counter, playerinfo, AImove)
        else:
            gameinputint = gameinput(listofmoves, counter, playerinfo, AImove)
    gameinputint = gameinput(listofmoves, counter, playerinfo, AImove)
    listofmoves.append(gameinputint)
    print(listofmoves)
    print(listofplaces)
    gameOverList = gameOver(listofplaces)
    if gameOverList[0]:
        GameOn = False
    counter = counter + 1
print('Game Over, it was a ', gameOverList[1])
# Out:
# - - -
# - - -
# - - -
# CounterFORwin is  0
# CounterFORdraw is  0
# CounterFORloss is  0
# CounterFORwin is  0
# CounterFORdraw is  0
# CounterFORloss is  0
# CounterFORwin is  0
# CounterFORdraw is  0
# CounterFORloss is  0
# CounterFORwin is  0
# CounterFORdraw is  0
# CounterFORloss is  0
# CounterFORwin is  0
# CounterFORdraw is  0
# CounterFORloss is  0
# CounterFORwin is  0
# CounterFORdraw is  0
# CounterFORloss is  0
# CounterFORwin is  0
# CounterFORdraw is  0
# CounterFORloss is  0
# CounterFORwin is  0
# CounterFORdraw is  0
# CounterFORloss is  0
# CounterFORwin is  0
# CounterFORdraw is  0
# CounterFORloss is  1
# please enter the input number of where you would like your piece to be placed 1
# please enter the input number of where you would like your piece to be placed 1
# [1]
# ['X', 'X', 'X', 'X', 'X', 'X', 'X', 'X', 'X']
# Game Over, it was a  Win By X

# %%
xxx------
x---x---x
---xxx---
------xxx
--x-x-x--
x--x--x--
-x--x--x-
--x--x--x

-oo------
o-o------
oo-------
----o---o
o-------o
o---o----
----oo---
---o-o---
---oo----
-------oo
------o-o
------oo-
----o-o--
--o---o--
--o-o----
---o--o--
o-----o--
o--o-----
----o--o-
-o-----o-
-o--o----
-----o--o
--o-----o
--o--o---
# Out:
#   Cell In[11], line 1
#     xxx------
#              ^
# SyntaxError: invalid syntax

# %%
def AI(playerinfo, listofplaces):
    CounterFORwin = 0
    CounterFORloss = 0
    CounterFORdraw = 0
    if playerinfo[0] == 'O':
        CPUpiece = 'X'
    else:
        CPUpiece = 'O'
    #make return an int
    winThing = 'Win By ' + CPUpiece
    looseThing = 'Win By ' + playerinfo[0]
    drawThing = 'Draw'
    i = 0
    for i in range(len(listofplaces)):
        if listofplaces[i] == '-':
            listofplaces[i] = CPUpiece
            if howManySpaces(listofplaces) > 0:
                j = 0
                for j in range(len(listofplaces)):
                    if listofplaces[i] == '-':
                        CPUpiece = pieceALTER(CPUpiece)
                        listofplaces[i] = CPUpiece
                        print(listofplaces)
                        if howManySpaces(listofplaces) > 0:
                            k = 0
                            for k in range(len(listofplaces)):
                                if listofplaces[i] == '-':
                                    CPUpiece = pieceALTER(CPUpiece)
                                    listofplaces[i] = CPUpiece
                                    print(listofplaces)
                                    if howManySpaces(listofplaces) > 0:
                                        l = 0
                                        for l in range(len(listofplaces)):
                                            if listofplaces[i] == '-':
                                                CPUpiece = pieceALTER(CPUpiece)
                                                listofplaces[i] = CPUpiece
                                                print(listofplaces)
                                                if howManySpaces(listofplaces) > 0:
                                                    m = 0
                                                    for m in range(len(listofplaces)):
                                                        if listofplaces[i] == '-':
                                                            CPUpiece = pieceALTER(CPUpiece)
                                                            listofplaces[i] = CPUpiece
                                                            print(listofplaces)
                                                            if howManySpaces(listofplaces) > 0:
                                                                n = 0
                                                                for n in range(len(listofplaces)):
                                                                    if listofplaces[i] == '-':
                                                                        CPUpiece = pieceALTER(CPUpiece)
                                                                        listofplaces[i] = CPUpiece
                                                                        print(listofplaces)
                                                                        if howManySpaces(listofplaces) > 0:
                                                                            o = 0
                                                                            for o in range(len(listofplaces)):
                                                                                if listofplaces[i] == '-':
                                                                                    CPUpiece = pieceALTER(CPUpiece)
                                                                                    listofplaces[i] = CPUpiece
                                                                                    print(listofplaces)
                                                                                    if howManySpaces(listofplaces) > 0:
                                                                                       p = 0
                                                                                       for p in range(len(listofplaces)):
                                                                                           if listofplaces[i] == '-':
                                                                                               CPUpiece = pieceALTER(CPUpiece)
                                                                                               listofplaces[i] = CPUpiece
                                                                                               print(listofplaces)
                                                                                               if howManySpaces(listofplaces) > 0:
                                                                                                   q = 0
                                                                                                   for q in range(len(listofplaces)):
                                                                                                       if listofplaces[i] == '-':
                                                                                                           CPUpiece = pieceALTER(CPUpiece)
                                                                                                           listofplaces[i] = CPUpiece
                                                                                                           print(listofplaces)
                                                                                                           if howManySpaces(listofplaces) > 0:
                                                                                                               print('DEBuG: WHY?!?!?!?!?!')
                                                                                                           else:
                                                                                                               answer = gameOver(listofplaces)
                                                                                                               if answer == winThing:
                                                                                                                   CounterFORwin = CounterFORwin + 1
                                                                                                               elif answer == drawThing:
                                                                                                                   CounterFORdraw = CounterFORdraw + 1
                                                                                                               else:
                                                                                                                   CounterFORloss = CounterFORloss + 1
                                                                                               else:
                                                                                                   answer = gameOver(listofplaces)
                                                                                                   if answer == winThing:
                                                                                                       CounterFORwin = CounterFORwin + 1
                                                                                                   elif answer == drawThing:
                                                                                                       CounterFORdraw = CounterFORdraw + 1
                                                                                                   else:
                                                                                                       CounterFORloss = CounterFORloss + 1
                                                                                    else:
                                                                                       answer = gameOver(listofplaces)
                                                                                       if answer == winThing:
                                                                                           CounterFORwin = CounterFORwin + 1
                                                                                       elif answer == drawThing:
                                                                                           CounterFORdraw = CounterFORdraw + 1
                                                                                       else:
                                                                                           CounterFORloss = CounterFORloss + 1
                                                                        else:
                                                                            answer = gameOver(listofplaces)
                                                                            if answer == winThing:
                                                                                CounterFORwin = CounterFORwin + 1
                                                                            elif answer == drawThing:
                                                                                CounterFORdraw = CounterFORdraw + 1
                                                                            else:
                                                                                CounterFORloss = CounterFORloss + 1
                                                            else:
                                                                answer = gameOver(listofplaces)
                                                                if answer == winThing:
                                                                    CounterFORwin = CounterFORwin + 1
                                                                elif answer == drawThing:
                                                                    CounterFORdraw = CounterFORdraw + 1
                                                                else:
                                                                    CounterFORloss = CounterFORloss + 1
                                                else:
                                                    answer = gameOver(listofplaces)
                                                    if answer == winThing:
                                                        CounterFORwin = CounterFORwin + 1
                                                    elif answer == drawThing:
                                                        CounterFORdraw = CounterFORdraw + 1
                                                    else:
                                                        CounterFORloss = CounterFORloss + 1
                                    else:
                                        answer = gameOver(listofplaces)
                                        if answer == winThing:
                                            CounterFORwin = CounterFORwin + 1
                                        elif answer == drawThing:
                                            CounterFORdraw = CounterFORdraw + 1
                                        else:
                                            CounterFORloss = CounterFORloss + 1
                        else:
                            answer = gameOver(listofplaces)
                            if answer == winThing:
                                CounterFORwin = CounterFORwin + 1
                            elif answer == drawThing:
                                CounterFORdraw = CounterFORdraw + 1
                            else:
                                CounterFORloss = CounterFORloss + 1
            else:
                answer = gameOver(listofplaces)
                if answer == winThing:
                    CounterFORwin = CounterFORwin + 1
                elif answer == drawThing:
                    CounterFORdraw = CounterFORdraw + 1
                else:
                    CounterFORloss = CounterFORloss + 1
            print('CounterFORwin is ', CounterFORwin)
            print('CounterFORdraw is ', CounterFORdraw)
            print('CounterFORloss is ', CounterFORloss)

# %%
a = 9 % 5
print(a)
# Out:
# 4

# %%
a = 'Win By '
winThing = 'Win By a'
looseThing = 'Win By b'
drawThing = 'Draw'
if (a == winThing) or (a == looseThing) or (a == drawThing):
    print('HI')
else:
    print('BOO')
# Out:
# BOO

# %%
def Banana(size):
    print(size + 122)

size = 122

def FROOT(size, Banana):
    Banana(size)

FROOT(size, Banana)
# Out:
# 244
