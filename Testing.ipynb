# %%
class TestClass:
    def __init__(self):
        self.variable = 0
    def TestFunc(self, variable):
        self.variable = variable
    

TC = TestClass()
variable = '99'
print(variable)
TC.TestFunc(variable)
print(TC.variable)
# Out:
# 99
# 99

# %%
class TestClass:
    def __init__(self, variable):
        self.variable = variable
Tc = TestClass(100)
Tc2 = TestClass(10)
print(Tc.variable)
print(Tc2.variable)
# Out:
# 100
# 10

# %%
# tuple things
answer = "1"

tuple1 = ("1", True, "2", False, "3", False, "4", False, "5", False)

i = 0
a = len(tuple1)
for i in range(a):
    if i % 2 == 0:
        if tuple[i - 1] == answer:
            print("you got it")
print("done")
# Out:
# done
