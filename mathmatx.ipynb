# %%
import time as t
import os
import random

class primes:
    class primelist:
        def isPrimeNumber(n1):
            n2 = 1
            count = 0
            while n2 <= n1:
                if n1 % n2 == 0:
                    count = count + 1
                n2 = n2 + 1
                if count > 2:
                    return False
            if count == 2:
                return True
        
        def primelist(start, end):
            n1 = start
            target = end
            prime_no_list = []
            i = 0
            while n1 <= target:#this ends the program when a spicific number is reached
            #while n1 <= n1:#this keeps going for ever
                trueORfalse = primes.primelist.isPrimeNumber(n1)
                if trueORfalse:
                    prime_no_list.append(n1)
                    #print (n1)
                    #t.sleep(0.1)
                n1 = n1 + 1
            return prime_no_list

    def factors(number):
        smallerNumber = number
        n1 = 2
        listONos = []
        while smallerNumber > 1:
            if smallerNumber % n1 == 0:
                listONos.append(n1)
                smallerNumber = smallerNumber // n1
            else:
                n1 += 1
        return listONos

# %%
start = 1475678456
end = 1475678865
c = primes.primelist.primelist(start, end)
print (c)
c = 0
#10000019
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 3
#       1 start = 1475678456
#       2 end = 1475678865
# ----> 3 c = primes.primelist.primelist(start, end)
#       4 print (c)
#       5 c = 0
#
# Cell In[4], line 26, in primes.primelist.primelist(start, end)
#      23 i = 0
#      24 while n1 <= target:#this ends the program when a spicific number is reached
#      25 #while n1 <= n1:#this keeps going for ever
# ---> 26     trueORfalse = primes.primelist.isPrimeNumber(n1)
#      27     if trueORfalse:
#      28         prime_no_list.append(n1)
#
# Cell In[4], line 10, in primes.primelist.isPrimeNumber(n1)
#       8 n2 = 1
#       9 count = 0
# ---> 10 while n2 <= n1:
#      11     if n1 % n2 == 0:
#      12         count = count + 1
#
# KeyboardInterrupt:

# %%
n1 = 229
if primes.primelist.isPrimeNumber(n1):
    print(True)
else:
    print(False)
# Out:
# True

# %%
def listMultipleX(alist):
    length = len(alist)
    i = 0
    for i in range (length):
        if i == 0:
            b = alist[0]
            a = 1
        if i > 0:
            a = alist[i]
        b = b * a
    return b
print(b)

# %%
number = 1145
b = primes.factors(number)
print(b)
# Out:
# [5, 229]

# %%
#amountOfPrimes = len(c)
#random.seed()
#d = random.randint(0, (amountOfPrimes - 1))
#print(d)

# %%
#amountOfPrimes = len(c)
#random.seed()
#d = random.randint(0, (amountOfPrimes - 1))
#print(d)

# %%
number = input("what number would you like to split into prime factors?")
def factors(number):
    smallerNumber = number
    n1 = 2
    listONos = []
    while smallerNumber > 1:
        if smallerNumber % n1 == 0:
            listONos.append(n1)
            smallerNumber = smallerNumber // n1
        else:
            n1 += 1
    return listONos
print(factors(int(number)))
# Out:
# what number would you like to split into prime factors? 1222
# [2, 13, 47]

# %%
import math
import sys

going = True
while going:
    length = input("How many simultanious equations would you like to solve? ")
    if int(length) > 20:
        print("More than 20 is too many")
        going = True
    elif int(length) < 2:
        print("Less than 2 is too few")
        going = True
    else:
        going = False

i = 0
listOfEqua = []
for i in range(int(length)):
    if (i + 1) == 1:
        extra = "st"
    elif (i + 1) == 2:
        extra = "nd"
    elif (i + 1) == 3:
        extra = "rd"
    else:
        extra = "th"
    a = str(i + 1)
    equa = input(f"What is your {a}{extra} simultanious equation? ")
    listOfEqua.append(equa)

print("Please make sure all your variables are on one side of the equation")

number1 = input("What is your first number to calculate the LCM of? ")
number2 = input("What is your second number to calculate the LCM of? ")

def factors(number):
    smallerNumber = int(number)
    n1 = 2
    listONos = []
    while smallerNumber > 1:
        if smallerNumber % n1 == 0:
            listONos.append(n1)
            smallerNumber = smallerNumber // n1
        else:
            n1 += 1
    return listONos

def LCM(number1, number2, factors):
    number = int(number1)
    a_list1 = factors(number)
    number = int(number2)
    a_list2 = factors(number)
    i = 0
    for i in range(len(a_list1)):
        j = 0
        while j < len(a_list2):
            if a_list1[i] == a_list2[j]:
                a_list2.pop(j)
                break
            j += 1
    a_list = a_list1 + a_list2
    return (math.prod(a_list))

#print(LCM(number1, number2, factors))  # test

strOfLetters = "qwertyuiopasdfghjklzxcvbnm"
listOfLettersa = []
for i in range(len(strOfLetters)):
    listOfLettersa.append(strOfLetters[i])

listOfSpecialCharacters = ['=', '+', '-']
indexForEaquals = []
indexOfVarslist = []

for j in range(len(listOfEqua)):
    howManyLetters = 0
    anEqual = 0
    plusesandminuses = 0
    i = 0
    indexOfVars = []
    listOfLetters = listOfLettersa.copy()

    for i in range(len(listOfEqua[j])):
        for a in range(len(listOfLetters)):
            if (listOfEqua[j])[i] == listOfLetters[a]:
                howManyLetters += 1
                indexOfVars.append(i)
                listOfLetters.remove(listOfLetters[a])
                listOfLetters.append("£")
                break

        if (listOfEqua[j])[i] == "=":
            anEqual += 1
            indexOfeaqual = i

        for b in range(len(listOfSpecialCharacters)):
            if (listOfEqua[j])[i] == listOfSpecialCharacters[b]:
                plusesandminuses += 1
    
    if len(indexOfVars) != int(length):
        print("Please put enough/less variables in next time")
        sys.exit()

    if anEqual > 1 or anEqual < 1:
        print("Please only put one '=' in next time")
        sys.exit()

    a = len(indexOfVars)
    b = indexOfVars[a - 1]
    if b >= indexOfeaqual:
        print("Please configure the equation to only have variables before the '=' sign")
        sys.exit
    else:
        indexForEaquals.append(indexOfeaqual)
    indexOfVarslist.append(indexOfVars)
    going = True
    y = 0

#a = max(listOfEqua, key=len)
#index = listOfEqua2.index(a)
#for q in range(len(listOfEqua)):
    #for z in range(len(a)):
        #if listOfEqua[(indexOfVarslist[q])[z]] == listOfEqua[(indexOfVarslist[q + 1])[z]]:
            #print("pass")
        #else:
            #print("please format your function so the variabes have the same index")
            
stufff = []
for j in range(len(listOfEqua):
    a = (indexOfVarslist[j])[0]
    print(a)
    aN1 = a - 1
    if aN1 < 0:
        correctA = 1
    #else:
        #for b in range(2):
            #for i in range(len(listOfSpecialCharacters)):
                #if listOfSpecialCharacters[i] == (indexOfVarslist[j])[aN1]:
                    #correctA = 1
                #else:
                    #correctA = int((listOfEqua[j])[aN1])
        
    stufff.append(correctA)

listOfEqua2 = listOfEqua
#step1
a = max(listOfEqua2, key=len)
index = listOfEqua2.index(a)
#if stuff[0] == stuff[1]:
    #
# Out:
#   Cell In[112], line 129
#     for j in range(len(listOfEqua):
#                                   ^
# SyntaxError: invalid syntax

# %% [markdown]
# import sys
# going = True
# while going:
#     length = input("How many equations would you like?")
#     if int(length) > 20:
#         print("More than 20 is too many")
#         going = True
#     elif int(length) < 2:
#         print("Less than 2 is too few")
#         going = True
#     else:
#         going = False
#
# strOfVars = "abcdefghijklmnopqrstuvwxyz"
# listOfVars = []
# for i in range(len(strOfVars)):
#     listOfVars.append(strOfVars[i])
# print("Please put a minus (if you want one) when this code asks you for a coefficient")
# ListOfVariables = []
# equals = []
# for i in range(int(length)):
#     if (i + 1) == 1:
#         extra = "st"
#     elif (i + 1) == 2:
#         extra = "nd"
#     elif (i + 1) == 3:
#         extra = "rd"
#     else:
#         extra = "th"
#     a = (str(i + 1) + extra)
#     firstEquationsListOfVariables = []
#     for j in range(int(length)):
#         if (j + 1) == 1:
#             extra2 = "st"
#         elif (j + 1) == 2:
#             extra2 = "nd"
#         elif (j + 1) == 3:
#             extra2 = "rd"
#         else:
#             extra2 = "th"
#         b = (str(j + 1) + extra2)
#         going = True
#         #while going:
#             #extra1 = list(input(f"Would you like your {a} equation's {b} variable to be positive?"))
#             #if extra1[0] == 'Y' or extra1[0] == 'y':
#                 #positive = True
#                 #going = False
#             #elif extra1[0] == 'N' or extra1[0] == 'n':
#                 #positive = False
#                 #going = False
#             #else:
#                 #print("Yes or No")
#                 #going = True
#         a_variable = int(input(f"What is your {a} equation's {b} varible's coefficient"))
#         firstEquationsListOfVariables.append(a_variable)
#     ListOfVariables.append(firstEquationsListOfVariables)
#     e = int(input("What does this equal?"))
#     equals.append(e)
#     body = ''
#     for q in range(len(firstEquationsListOfVariables)):
#         body = body + firstEquationsListOfVariables[q] + listOfVars[q]
#         if q + 1 != len(firstEquationsListOfVariables):
#             body = body + "+"
#     print("Your ", a, "equation is: ", body, "=", e)
#
# def solve(ListOfVariables, equals, number1, number2):
#     list1 = ListOfVariables[number1 - 1]
#     list2 = ListOfVariables[number2 - 1]
#     print(list1)
#     print(list2)
#     length = len(list1)
#     multL1 = list2[0]
#     multL2 = list1[0]
#     print(multL1)
#     print(multL2)
#     list1.pop(0)
#     list2.pop(0)
#     for i in range(length - 1):
#         list1[i] = list1[i] * int(multL1)
#         list2[i] = list2[i] * int(multL2)
#     ListOfVariables[number1 - 1] = list1
#     ListOfVariables[number2 - 1] = list2
#     e1 = int(equals[number1 - 1])
#     e2 = int(equals[number2 - 1])
#     e1 = e1 * int(multL1)
#     e2 = e2 * int(multL2)
#     equals[number1 - 1] = e1
#     equals[number2 - 1] = e2
#     return [ListOfVariables, equals]
#
# #1st solve
# solves = len(ListOfVariables)
# tiers = solves - 1
# megasolves = int(length)
# for k in range(megasolves):
#     for j in range(tiers):
#         solves = solves - 1
#         for i in range(solves):
#             number1 = i
#             number2 = i + 1
#             ListOfVariables = solve(ListOfVariables, equals, number1, number2)[0]
#             equals = solve(ListOfVariables, equals, number1, number2)[1]
#             print(ListOfVariables)
#             print(equals)
#     print(ListOfVariables)
#     print(equals)

# %%
.
..
...
....
.....
......

# %%
going = True
while going:
    length = input("How many equations would you like?")
    if int(length) > 20:
        print("More than 20 is too many")
        going = True
    elif int(length) < 2:
        print("Less than 2 is too few")
        going = True
    else:
        going = False

strOfVars = "abcdefghijklmnopqrstuvwxyz"
listOfVars = []
for i in range(len(strOfVars)):
    listOfVars.append(strOfVars[i])
print("Please put a minus (if you want one) when this code asks you for a coefficient")
ListOfVariables = []
equals = []
for i in range(int(length)):
    if (i + 1) == 1:
        extra = "st"
    elif (i + 1) == 2:
        extra = "nd"
    elif (i + 1) == 3:
        extra = "rd"
    else:
        extra = "th"
    a = (str(i + 1) + extra)
    firstEquationsListOfVariables = []
    for j in range(int(length)):
        if (j + 1) == 1:
            extra2 = "st"
        elif (j + 1) == 2:
            extra2 = "nd"
        elif (j + 1) == 3:
            extra2 = "rd"
        else:
            extra2 = "th"
        b = (str(j + 1) + extra2)
        going = True
        #while going:
            #extra1 = list(input(f"Would you like your {a} equation's {b} variable to be positive?"))
            #if extra1[0] == 'Y' or extra1[0] == 'y':
                #positive = True
                #going = False
            #elif extra1[0] == 'N' or extra1[0] == 'n':
                #positive = False
                #going = False
            #else:
                #print("Yes or No")
                #going = True
        a_variable = int(input(f"What is your {a} equation's {b} varible's coefficient"))
        firstEquationsListOfVariables.append(a_variable)
    ListOfVariables.append(firstEquationsListOfVariables)
    e = int(input("What does this equal?"))
    equals.append(e)
    body = ''
    for q in range(len(firstEquationsListOfVariables)):
        body = body + str(firstEquationsListOfVariables[q]) + str(listOfVars[q])
        if q + 1 != len(firstEquationsListOfVariables):
            body = body + "+"
    print("Your ", a, "equation is: ", body, "=", e)

def solve(ListOfVariables, equals, number1, number2):
    list1 = ListOfVariables[number1]
    list2 = ListOfVariables[number2]
    list3 = []
    for i in range(len(list1)):
        list3.append('')
    print(list1)
    print(list2)
    length = len(list1)
    multL1 = list2[0]
    multL2 = list1[0]
    print(multL1)
    print(multL2)
    for i in range(length):
        list1[i] = list1[i] * int(multL1)
        list2[i] = list2[i] * int(multL2)
        list3[i] = list2[i] - list1[i]
    e1 = int(equals[number1])
    e2 = int(equals[number2])
    e1 = e1 * int(multL1)
    e2 = e2 * int(multL2)
    newE = [e1, e2]
    return [list3, newE]

#1st solve
solves = len(ListOfVariables)
tiers = solves - 1
megasolves = int(length)
for k in range(megasolves):
    for j in range(tiers):
        solves = solves - 1
        for i in range(solves):
            number1 = i
            number2 = i + 1
            list3, newE = solve(ListOfVariables, equals, number1, number2)
            print(ListOfVariables)
            print(equals)
            print(list3)
            print(newE)
    print(ListOfVariables)
    print(equals)
# Out:
# How many equations would you like? 2
# Please put a minus (if you want one) when this code asks you for a coefficient
# What is your 1st equation's 1st varible's coefficient 3
# What is your 1st equation's 2nd varible's coefficient 2
# What does this equal? 7
# Your  1st equation is:  3a+2b = 7
# What is your 2nd equation's 1st varible's coefficient 4
# What is your 2nd equation's 2nd varible's coefficient 1
# What does this equal? 6
# Your  2nd equation is:  4a+1b = 6
# [3, 2]
# [4, 1]
# 4
# 3
# [[12, 8], [12, 3]]
# [7, 6]
# [0, -5]
# [28, 18]
# [[12, 8], [12, 3]]
# [7, 6]
# [[12, 8], [12, 3]]
# [7, 6]

# %%
going = True
while going:
    length = input("How many equations would you like?")
    if int(length) > 20:
        print("More than 20 is too many")
        going = True
    elif int(length) < 2:
        print("Less than 2 is too few")
        going = True
    else:
        going = False

strOfVars = "abcdefghijklmnopqrstuvwxyz"
listOfVars = []
for i in range(len(strOfVars)):
    listOfVars.append(strOfVars[i])
print("Please put a minus (if you want one) when this code asks you for a coefficient")

ListOfVariables = []
equals = []

for i in range(int(length)):
    if (i + 1) == 1:
        extra = "st"
    elif (i + 1) == 2:
        extra = "nd"
    elif (i + 1) == 3:
        extra = "rd"
    else:
        extra = "th"
    a = (str(i + 1) + extra)
    firstEquationsListOfVariables = []
    for j in range(int(length)):
        if (j + 1) == 1:
            extra2 = "st"
        elif (j + 1) == 2:
            extra2 = "nd"
        elif (j + 1) == 3:
            extra2 = "rd"
        else:
            extra2 = "th"
        b = (str(j + 1) + extra2)
        a_variable = int(input(f"What is your {a} equation's {b} variable's coefficient: "))
        firstEquationsListOfVariables.append(a_variable)
    ListOfVariables.append(firstEquationsListOfVariables)
    e = int(input("What does this equal? "))
    equals.append(e)
    body = ''
    for q in range(len(firstEquationsListOfVariables)):
        body = body + str(firstEquationsListOfVariables[q]) + str(listOfVars[q])
        if q + 1 != len(firstEquationsListOfVariables):
            body = body + "+"
    print("Your", a, "equation is:", body, "=", e)
# Out:
# How many equations would you like? 3
# Please put a minus (if you want one) when this code asks you for a coefficient
# What is your 1st equation's 1st variable's coefficient:  2
# What is your 1st equation's 2nd variable's coefficient:  1
# What is your 1st equation's 3rd variable's coefficient:  3
# What does this equal?  13
# Your 1st equation is: 2a+1b+3c = 13
# What is your 2nd equation's 1st variable's coefficient:  1
# What is your 2nd equation's 2nd variable's coefficient:  2
# What is your 2nd equation's 3rd variable's coefficient:  2
# What does this equal?  11
# Your 2nd equation is: 1a+2b+2c = 11
# What is your 3rd equation's 1st variable's coefficient:  3
# What is your 3rd equation's 2nd variable's coefficient:  3
# What is your 3rd equation's 3rd variable's coefficient:  1
# What does this equal?  12
# Your 3rd equation is: 3a+3b+1c = 12

# %%
def solve(ListOfVariables, equals, number1, number2, column):
    list1 = ListOfVariables[number1]
    list2 = ListOfVariables[number2]
    multL1 = list2[column]
    multL2 = list1[column]
    list3 = []
    for i in range(len(list1)):
        # subtract scaled pivot row from current row
        list3.append(list2[i]*multL2 - list1[i]*multL1)
    e1 = equals[number1]
    e2 = equals[number2]
    newE = e2*multL2 - e1*multL1
    return [list3, newE]


# full elimination

for col in range(int(length)):
    if col >= len(ListOfVariables):  # col cannot be more than number of rows
        break
    # safety: only check pivot if the row has enough columns
    if col >= len(ListOfVariables[col]):
        continue
    if ListOfVariables[col][col] == 0:
        continue
    for i in range(col + 1, len(ListOfVariables)):
        # safety: only eliminate if row i has enough columns
        if col >= len(ListOfVariables[i]):
            continue
        list3, newE = solve(ListOfVariables, equals, col, i, col)
        ListOfVariables[i] = list3
        equals[i] = newE
        
print()
print("After elimination:")
for i in range(int(length)):
    print(ListOfVariables[i], "=", equals[i])
    
a = int(length) - (q + 1)
b = ListOfVariables[a][a]
c = equals[a]
d = c / b
#listOfVars
e = listOfVars[a - q]
print(f"{e} is: {d}")
f = len(ListOfVariables[0])
for i in range(len(ListOfVariables)):
    g = ListOfVariables[i][f - 1]
    ListOfVariables[i].pop(f - 1)
    equals[i] = int(equals[i]) - d
# Out:
# After elimination:
# [2, 1, 3] = 13
# [0, 3, 1] = 9
# [0, 0, -24] = -72
# y is: 6.5

# %%
for col in range(int(length)):
    if col >= len(ListOfVariables):
        break
    if col >= len(ListOfVariables[col]):
        continue
    if ListOfVariables[col][col] == 0:
        continue
    for i in range(col + 1, len(ListOfVariables)):
        if col >= len(ListOfVariables[i]):
            continue
        list3, newE = solve(ListOfVariables, equals, col, i, col)
        ListOfVariables[i] = list3
        equals[i] = newE

print("\nAfter elimination:")
for i in range(int(length)):
    print(ListOfVariables[i], "=", equals[i])

# back-substitution in your style, NO popping
answers = [0]*int(length)
for i in range(int(length)-1, -1, -1):
    total = equals[i]
    for j in range(i+1, int(length)):
        total -= ListOfVariables[i][j]*answers[j]
    answers[i] = total / ListOfVariables[i][i]

print("\nSolutions:")
for i in range(int(length)):
    print(listOfVars[i], "=", answers[i])
# Out:
# After elimination:
# [2] = 13
# [0] = 9216
# [0] = -442368
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[190], line 25
#      23     for j in range(i+1, int(length)):
#      24         total -= ListOfVariables[i][j]*answers[j]
# ---> 25     answers[i] = total / ListOfVariables[i][i]
#      27 print("\nSolutions:")
#      28 for i in range(int(length)):
#
# IndexError: list index out of range

# %%
def solve(ListOfVariables, equals, number1, number2, column):
    list1 = ListOfVariables[number1]
    list2 = ListOfVariables[number2]
    # Make sure both rows are the same length
    length = min(len(list1), len(list2))
    multL1 = list2[column]
    multL2 = list1[column]
    list3 = []
    for i in range(length):
        list3.append(list2[i]*multL2 - list1[i]*multL1)
    e1 = equals[number1]
    e2 = equals[number2]
    newE = e2*multL2 - e1*multL1
    return [list3, newE]

# full elimination
for col in range(int(length)):
    if col >= len(ListOfVariables):
        break
    if col >= len(ListOfVariables[col]):
        continue
    if ListOfVariables[col][col] == 0:
        continue
    for i in range(col + 1, len(ListOfVariables)):
        if col >= len(ListOfVariables[i]):
            continue
        list3, newE = solve(ListOfVariables, equals, col, i, col)
        ListOfVariables[i] = list3
        equals[i] = newE

print("\nAfter elimination:")
for i in range(int(length)):
    print(ListOfVariables[i], "=", equals[i])

# back-substitution (same style)
answers = [0]*int(length)
for i in range(int(length)-1, -1, -1):
    total = equals[i]
    for j in range(i+1, len(ListOfVariables[i])):
        total -= ListOfVariables[i][j]*answers[j]
    answers[i] = total / ListOfVariables[i][i]

print("\nSolutions:")
for i in range(int(length)):
    print(listOfVars[i], "=", answers[i])
# Out:
# After elimination:
# [2] = 13
# [0] = 18432
# [0] = -884736
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[192], line 41
#      39     for j in range(i+1, len(ListOfVariables[i])):
#      40         total -= ListOfVariables[i][j]*answers[j]
# ---> 41     answers[i] = total / ListOfVariables[i][i]
#      43 print("\nSolutions:")
#      44 for i in range(int(length)):
#
# IndexError: list index out of range

# %%
def solve(ListOfVariables, equals, number1, number2, column):
    list1 = ListOfVariables[number1]
    list2 = ListOfVariables[number2]
    # Make sure both rows are the same length
    length = min(len(list1), len(list2))
    multL1 = list2[column]
    multL2 = list1[column]
    list3 = []
    for i in range(length):
        list3.append(list2[i]*multL2 - list1[i]*multL1)
    e1 = equals[number1]
    e2 = equals[number2]
    newE = e2*multL2 - e1*multL1
    return [list3, newE]

# full elimination
for col in range(int(length)):
    if col >= len(ListOfVariables):
        break
    if col >= len(ListOfVariables[col]):
        continue
    if ListOfVariables[col][col] == 0:
        continue
    for i in range(col + 1, len(ListOfVariables)):
        if col >= len(ListOfVariables[i]):
            continue
        list3, newE = solve(ListOfVariables, equals, col, i, col)
        ListOfVariables[i] = list3
        equals[i] = newE

print("\nAfter elimination:")
for i in range(int(length)):
    print(ListOfVariables[i], "=", equals[i])

# back-substitution (same style)
answers = [0]*int(length)
for i in range(int(length)-1, -1, -1):
    total = equals[i]
    for j in range(i+1, len(ListOfVariables[i])):
        total -= ListOfVariables[i][j]*answers[j]
    answers[i] = total / ListOfVariables[i][i]

print("\nSolutions:")
for i in range(int(length)):
    print(listOfVars[i], "=", answers[i])
# Out:
# After elimination:
# [2] = 13
# [0] = 36864
# [0] = -1769472
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[194], line 41
#      39     for j in range(i+1, len(ListOfVariables[i])):
#      40         total -= ListOfVariables[i][j]*answers[j]
# ---> 41     answers[i] = total / ListOfVariables[i][i]
#      43 print("\nSolutions:")
#      44 for i in range(int(length)):
#
# IndexError: list index out of range

# %%
def solve(ListOfVariables, equals, number1, number2, column):
    list1 = ListOfVariables[number1]
    list2 = ListOfVariables[number2]
    # keep full length
    length = len(list1)
    multL1 = list2[column]
    multL2 = list1[column]
    list3 = []
    for i in range(length):
        list3.append(list2[i]*multL2 - list1[i]*multL1)
    e1 = equals[number1]
    e2 = equals[number2]
    newE = e2*multL2 - e1*multL1
    return [list3, newE]

# elimination loop
num_rows = len(ListOfVariables)
num_cols = len(ListOfVariables[0])

for col in range(num_cols):  # loop by column, not by length
    if col >= num_rows:      # stop if column index exceeds row count
        break
    if ListOfVariables[col][col] == 0:
        continue
    for i in range(col + 1, num_rows):
        list3, newE = solve(ListOfVariables, equals, col, i, col)
        ListOfVariables[i] = list3
        equals[i] = newE

print("\nAfter elimination:")
for i in range(int(length)):
    print(ListOfVariables[i], "=", equals[i])

# back-substitution (keeps your style)
answers = [0]*int(length)
for i in range(int(length)-1, -1, -1):
    total = equals[i]
    for j in range(i+1, int(length)):
        total -= ListOfVariables[i][j]*answers[j]
    answers[i] = total / ListOfVariables[i][i]

print("\nSolutions:")
for i in range(int(length)):
    print(listOfVars[i], "=", answers[i])
# Out:
# After elimination:
# [2] = 13
# [0] = 147456
# [0] = -7077888
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[198], line 40
#      38     for j in range(i+1, int(length)):
#      39         total -= ListOfVariables[i][j]*answers[j]
# ---> 40     answers[i] = total / ListOfVariables[i][i]
#      42 print("\nSolutions:")
#      43 for i in range(int(length)):
#
# IndexError: list index out of range

# %%
def solve(ListOfVariables, equals, number1, number2, column):
    list1 = ListOfVariables[number1]
    list2 = ListOfVariables[number2]
    length = len(list1)  # full length
    multL1 = list2[column]
    multL2 = list1[column]
    list3 = []
    for i in range(length):
        list3.append(list2[i]*multL2 - list1[i]*multL1)
    e1 = equals[number1]
    e2 = equals[number2]
    newE = e2*multL2 - e1*multL1
    return [list3, newE]

# elimination loop (your style)
num_rows = len(ListOfVariables)
num_cols = len(ListOfVariables[0])

for col in range(num_cols):
    if col >= num_rows:
        break
    if ListOfVariables[col][col] == 0:
        continue
    for i in range(col + 1, num_rows):
        list3, newE = solve(ListOfVariables, equals, col, i, col)
        ListOfVariables[i] = list3
        equals[i] = newE

print("\nAfter elimination:")
for i in range(num_rows):
    print(ListOfVariables[i], "=", equals[i])

# back-substitution
answers = [0]*num_cols
for i in range(num_rows-1, -1, -1):
    total = equals[i]
    for j in range(i+1, num_cols):
        total -= ListOfVariables[i][j]*answers[j]
    answers[i] = total / ListOfVariables[i][i]

print("\nSolutions:")
for i in range(num_cols):
    print(listOfVars[i], "=", answers[i])
# Out:
# After elimination:
# [2] = 13
# [0] = 294912
# [0] = -14155776
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[200], line 39
#      37     for j in range(i+1, num_cols):
#      38         total -= ListOfVariables[i][j]*answers[j]
# ---> 39     answers[i] = total / ListOfVariables[i][i]
#      41 print("\nSolutions:")
#      42 for i in range(num_cols):
#
# IndexError: list index out of range
