# %%
list_of_probibles = [123, 23456, 45, 57, 9876, 54321]
whitch_one = input('which one?')
# Out:
# which one? 1

# %%
import sys
class find_probable(list_of_probibles, whitch_one):
    if len(list_of_probibles) < whitch_one:
        sys.exit()
    def probability(list_of_probibles, whitch_one):
        denominator = sum(list_of_probibles)
        numerator = list_of_probibles[(whitch_one - 1)]
        full_list = [numerator, denominator]
        return full_list
    
    def which_one(full_list):
        numerator = full_list[0]
        denominator = full_list[1]
        out_of_one = float(numerator / denominator)
        percent = round(out_of_one * 100, 3)
        listofstuff = [out_of_one, percent, full_list]
        return listofstuff
    
    list_of_probibles = []
    for i in range(how_many):
        list_of_probibles.append(typea)
    full_list = probability(list_of_probibles, whitch_one)
    list_of_stuff = which_one(full_list)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 2
#       1 import sys
# ----> 2 class find_probable(list_of_probibles, whitch_one):
#       3     if len(list_of_probibles) < whitch_one:
#       4         sys.exit()
#
# TypeError: metaclass conflict: the metaclass of a derived class must be a (non-strict) subclass of the metaclasses of all its bases

# %%
a_class = find_probable(list_of_probibles, a)
a.list_of_stuff
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 a_class = find_probable(list_of_probibles, a)
#       2 a.list_of_stuff
#
# NameError: name 'find_probable' is not defined
