# %%
from sys import exit
import os

# %%
def key():
    print ('this is the key')
    box = '|---|\n'
    side = '|'
    side2 = '|\n'
    print('\n', box, side, 'N', side2, box)
    print('that means it can be any colour piece')
    print('')
    print('\n', box, side, 'W', side2, box)
    print('that means it is a white piece')
    print('')
    print('\n', box, side, 'Y', side2, box)
    print('that means it is a yellow piece')
    print('')
    print('\n', box, side, 'R', side2, box)
    print('that means it is a red piece')
    print('')
    print('\n', box, side, 'B', side2, box)
    print('that means it is a blue piece')
    print('')
    print('\n', box, side, 'O', side2, box)
    print('that means it is a orange piece')
    print('')
    print('\n', box, side, 'G', side2, box)
    print('that means it is a green piece')
    print('')
    print('\n', topnbottomnmiddle, side, 'N', side, 'W', side, 'N', side, '\n', topnbottomnmiddle, side, 'W', side, 'W', side, 'W', side, '\n', topnbottomnmiddle, side, 'N', side, 'W', side, 'N', side, '\n', topnbottomnmiddle)
    print('that shows the white cross')
    print('')
    print('\n', topnbottomnmiddle, side, 'N', side, 'N', side, 'N', side, '\n', topnbottomnmiddle, side, 'N', side, 'O', side, 'N', side, '\n', topnbottomnmiddle, side, 'N', side, 'N', side, 'N', side, '\n', topnbottomnmiddle)
    print('\n', topnbottomnmiddle, side, 'N', side, 'Y', side, 'N', side, '\n', topnbottomnmiddle, side, 'W', side, 'W', side, 'W', side, '\n', topnbottomnmiddle, side, 'N', side, 'W', side, 'N', side, '\n', topnbottomnmiddle)
    print('that means that the white cross is incomplete and the top bit that should be white is yellow, it alse shows that the yellow bit is towards the orange')
    print('')
    print('you read out the position of the pieces like this')
    print('side 1: G, W, R, W, W, W, O, W, B side 2: O, Y, O, G, R, B, R, B, B')
    print('that would be this,')
    print('\n', topnbottomnmiddle, side, 'G', side, 'W', side, 'R', side, '\n', topnbottomnmiddle, side, 'W', side, 'W', side, 'W', side, '\n', topnbottomnmiddle, side, 'O', side, 'W', side, 'B', side, '\n', topnbottomnmiddle)
    print('\n', topnbottomnmiddle, side, 'N', side, 'Y', side, 'N', side, '\n', topnbottomnmiddle, side, 'W', side, 'W', side, 'W', side, '\n', topnbottomnmiddle, side, 'N', side, 'W', side, 'N', side, '\n', topnbottomnmiddle)
    print('')
    print('')

# %%
topnbottomnmiddle = '|---|---|---|\n'
global topnbottomnmiddle
side = '|'
global side

# %%
def intaker(face):
    personput = input(f'read out your {face} face')
    out = list(personput)
    while a in range (len(out)):
        if (len(out)) != 9:
            print('do it properly next time')
            exit()
        if out[i] == 'W' or 'Y' or 'R' or 'B' or 'G' or 'O':
            a = a + 1
        else:
            print('do it properly, with capitals next time')
            exit()
    colours = {
      "red": "R",
      "green": "G",
      "orange": "O",
      "blue": "B",
      "yellow": "Y",
      "white": "W"
    }
    a = 0
    colour = colours[face]
    othercolour = list_of_face[4]
    if colour == othercolour:
        a = 1
    else:
        print(f'do the {face} face next time')
        exit()
    return out

# %%
class cross:
    def __init__(whitenyellow):
        #if WnY is 0 then white else yellow
        cross.whitenyellow = whitenyellow
    
    def iscross():
        a = 0
        crosslistindex = [1, 3, 4, 5, 7]
        crosslist = []
        truelist = []
        if cross.whitenyellow == 0:
            colour = 'W'
        else:
            colour = 'Y'
        crossin = intaker(colour)
        for i in range (len(crosslist)):
            letter = crosslist[i]
            if letter == colour:
                truelist.append(True)
        if len(truelist) == 5:
            return True
        else:
            return False
    
    def checkEdge(list_of_face, colour):
        edgepiece = [1, 3, 5, 7]
        iposition = ['up', 'left', 'right', 'down']
        if_is_position = []
        for i in range (len(edgepiece)):
            index = edgepiece[i]
            po = iposition[i]
            edgecolour = list_of_face[index]
            if edgecolour == colour:
                if_is_position.append(po)
        return if_is_position
            
    class whiteside:
        def daisyknower():#do they know the daisy
            #do they know how to do the daisy
            daisy = input('do you know how to do the daisy (the yellow surrounded by correct white\'s?)')
            print(daisy)
            if (daisy == 'yes') or (daisy == 'Yes') or (daisy == 'YEs') or (daisy == 'YES') or (daisy == 'y') or (daisy == 'Y'):
                print('then do it!!!')
                print('')
                print('')
                print('')                
                return True
            elif (daisy == 'no') or (daisy == 'No') or (daisy == 'NO') or (daisy == 'n') or (daisy == 'N'):
                print('')
                print('')
                print('')
                return False
            else:
                print('Enter Yes or No next time')
                exit()

        def daisydo_er():
            e = 1
            #green
            print(f'step {e}:')
            print('move the cube so that the green bit of the white and green edge piece is touching the green center piece on the red side')
            print('such as this')
            print('\n', topnbottomnmiddle, side, 'N', side, 'N', side, 'N', side, '\n', topnbottomnmiddle, side, 'N', side, 'G', side, 'N', side, '\n', topnbottomnmiddle, side, 'N', side, 'G', side, 'N', side, '\n', topnbottomnmiddle)
            print('\n', topnbottomnmiddle, side, 'N', side, 'W', side, 'N', side, '\n', topnbottomnmiddle, side, 'N', side, 'R', side, 'N', side, '\n', topnbottomnmiddle, side, 'N', side, 'N', side, 'N', side, '\n', topnbottomnmiddle)
            print('')
            print('make the red side face towards you and twist the top layer 90° to your left, then make the yellow side face towards you.')
            print('such as this')
            print('\n', topnbottomnmiddle, side, 'N', side, 'N', side, 'N', side, '\n', topnbottomnmiddle, side, 'N', side, 'G', side, 'N', side, '\n', topnbottomnmiddle, side, 'N', side, 'G', side, 'N', side, '\n', topnbottomnmiddle)
            print('\n', topnbottomnmiddle, side, 'N', side, 'W', side, 'N', side, '\n', topnbottomnmiddle, side, 'N', side, 'Y', side, 'N', side, '\n', topnbottomnmiddle, side, 'N', side, 'N', side, 'N', side, '\n', topnbottomnmiddle)
            e = e + 1
            #red
            face = 'red'
            cross.whiteside.daisydo_er1(face, e)
            e = e + 1
            #green
            face = 'green'
            cross.whiteside.daisydo_er1(face, e)
            e = e + 1
            #orange
            face = 'orange'
            cross.whiteside.daisydo_er1(face, e)
            e = e + 1
            #blue
            face = 'blue'
            cross.whiteside.daisydo_er1(face, e)
            e = e + 1
            #white
            face = 'white'
            cross.whiteside.daisydo_er1(face, e)
            e = e + 1
            #yellow
            face = 'yellow'
            cross.whiteside.daisydo_er1(face, e)
        
        def daisydo_er1(face, e):
            colour = 'W'
            if (face == 'red') or (face == 'orange') or (face == 'blue') or (face == 'green'):
                print('make the yellow face point towards you')
            print(f'step {e}:')
            print(f'make your {face} face point up.')
            print('')
            print('')
            list_of_face = intaker(face)
            listofwhere = checkEdge(list_of_face, colour)
            if len(listofwhere) > 0:
                return False
            try:
                isup = listofwhere.index('up')
            except:
                print('just thinking')
            if face == 'red':
                alist = intaker("white")
                athing = alist[7]
                if athing == 'B':
                    print('make it look like this')
                    print('\n', topnbottomnmiddle, side, 'N', side, 'N', side, 'N', side, '\n', topnbottomnmiddle, side, 'N', side, 'R', side, 'W', side, '\n', topnbottomnmiddle, side, 'N', side, 'N', side, 'N', side, '\n', topnbottomnmiddle)

# %%
def finaldoer():
    #this is the key
    key()
    #this is to know if there is a white cross
    whitenyellow = 0
    whitecrosstrue = cross.iscross()
    if whitecrosstrue == False:
        knowdaisy = cross.whiteside.daisyknower()
        if knowdaisy == False:
            cross.whiteside.daisydo_er()

# %%
finaldoer()
# Out:
# this is the key
#
#  |---|
#  | N |
#  |---|
#
# that means it can be any colour piece
#
#
#  |---|
#  | W |
#  |---|
#
# that means it is a white piece
#
#
#  |---|
#  | Y |
#  |---|
#
# that means it is a yellow piece
#
#
#  |---|
#  | R |
#  |---|
#
# that means it is a red piece
#
#
#  |---|
#  | B |
#  |---|
#
# that means it is a blue piece
#
#
#  |---|
#  | O |
#  |---|
#
# that means it is a orange piece
#
#
#  |---|
#  | G |
#  |---|
#
# that means it is a green piece
#
#
#  |---|---|---|
#  | N | W | N |
#  |---|---|---|
#  | W | W | W |
#  |---|---|---|
#  | N | W | N |
#  |---|---|---|
#
# that shows the white cross
#
#
#  |---|---|---|
#  | N | N | N |
#  |---|---|---|
#  | N | O | N |
#  |---|---|---|
#  | N | N | N |
#  |---|---|---|
#
#
#  |---|---|---|
#  | N | Y | N |
#  |---|---|---|
#  | W | W | W |
#  |---|---|---|
#  | N | W | N |
#  |---|---|---|
#
# ...
